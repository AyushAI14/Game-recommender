# %%
import pandas as pd # type: ignore

# %%
# df  = pd.read_csv("/home/ayush/Documents/AI/Machine_Learning/Projects/Game-recommender/Dataset/Free-to-play games.txt",delimiter=',')
# df

# %%
# df.to_csv("/home/ayush/Documents/AI/Machine_Learning/Projects/Game-recommender/Dataset/free-games.csv",index=False)

# %%
convertedCsv = pd.read_csv("/home/ayush/Documents/AI/Machine_Learning/Projects/Game-recommender/Dataset/free-games.csv")
convertedCsv
# Out:
#                             title  \
# 0                       Tarisland
# 1                     Overwatch 2
# 2             PUBG: BATTLEGROUNDS
# 3                        Enlisted
# 4                  Genshin Impact
# ..                            ...
# 323               Ragnarok Online
# 324             Entropia Universe
# 325                Anarchy Online
# 326  The Lord of the Rings Online
# 327                         Tibia
#
#                                           thumbnail  \
# 0    https://www.freetogame.com/g/582/thumbnail.jpg
# 1    https://www.freetogame.com/g/540/thumbnail.jpg
# 2    https://www.freetogame.com/g/516/thumbnail.jpg
# 3    https://www.freetogame.com/g/508/thumbnail.jpg
# 4    https://www.freetogame.com/g/475/thumbnail.jpg
# ..                                              ...
# 323  https://www.freetogame.com/g/335/thumbnail.jpg
# 324   https://www.freetogame.com/g/17/thumbnail.jpg
# 325  https://www.freetogame.com/g/336/thumbnail.jpg
# ...
